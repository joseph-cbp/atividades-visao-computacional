# %% [markdown]
# # M1A2 - Manipulação de arrays com NumPy

# %% [markdown]
# Nessa aula iremos aprender como manipular matriz e vetores utilizando [NumPY](https://numpy.org/)
#
# Esse notebook está estruturado da seguinte forma.
#
# - Instalação
# - Operações básicas com vetores
# - Operaçõões básicas com matrizes
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Instalação e Importação da Biblioteca

# %%
# !pip install numpy

# %%
import numpy as np

# %% [markdown]
# ## Operações Básicas com Vetores

# %% [markdown]
# Primeiro vamos criar vetores para que possamos entender como eles são representados, e como podemos manipular eles.
#
# Nesse exemplos, vamos utilizar os vetores $\vec{u}$ e $\vec{v}$ com coordenadas $(1, 3)$ e $(3, 1)$ respectivamente como ilustrado na imagem abaixo.
#
# ![vetores u e v](vetores.png)

# %%
# Criando vetores.
u = np.array([1, 3])
v = np.array([3, 1])

# %% [markdown]
# Operações feitas individualmente nas dimensões do vetores como substração e adição podem ser feitas utilizando os operadores $-$ e $+$.

# %%
y = u - v
w = u + v

print(f"Vetor y: {y}\nVetor w: {w}")
# Out:
# Vetor y: [-2  2]
# Vetor w: [4 4]

# %% [markdown]
# Analogamente podemos visualizar esses resultados no plano cartesiano.
#
# ![subtração e adição com u e v](sub-add-vecs.png)

# %% [markdown]
# Multiplicação e divisão são feitas elemento por elemento.
#
# Com essa multiplicação podemos realizar o produto escalar, por exemplo $\alpha * \vec{u}$

# %%
a = u / v
b = u * v

print(f"Vetor a: {a}\nVetor b: {b}")

alpha = 2
escalar = alpha * u
print(f"Produtor escalar de u por alpha: {escalar}")
# Out:
# Vetor a: [0.33333333 3.        ]
# Vetor b: [3 3]
# Produtor escalar de u por alpha: [2 6]

# %% [markdown]
# Também é possível realizar operações geométrica como produto interno e vetorial.

# %%
interno = np.dot(u, v)


# Para o produto vetorial iremos utilizar vetores tridimensionais.
u3 = np.array([1, 3, 1])
v3 = np.array([3, 1, 1])
vetorial = np.cross(u3, v3)

print(f"Resultado produto interno: {interno}\nResutlado produto vetorial: {vetorial}")
# Out:
# Resultado produto interno: 6
# Resutlado produto vetorial: [ 2  2 -8]

# %% [markdown]
# ## Operações Básicas com Matrizes

# %% [markdown]
# A primeira coisa a compreender é como representar matrizes. Analogamente a vetores, em NumPy matrizes são vetores bidimesionais.
#
# Vamos fazer alguns exemplos e observar que podemos reproduzir todas as operações.

# %%
I = np.array([[1, 0],[0, 1]])
A = np.array([[2, 1],[1, 2]])

# %% [markdown]
# De maneira semelhante quando utilizamos vetores as operações podem ser realizadas elemento a elemento, ou seguindo a algebra que estamos familiarizados.

# %%
B = A + I

print(f"Matriz A:\n{A}\n\nMatriz Identidade:\n{I}\n\nMatriz B = A + I:\n{B}")
# Out:
# Matriz A:
# [[2 1]
#  [1 2]]
#
# Matriz Identidade:
# [[1 0]
#  [0 1]]
#
# Matriz B = A + I:
# [[3 1]
#  [1 3]]

# %%
B = A - I

print(f"Matriz A:\n{A}\n\nMatriz Identidade:\n{I}\n\nMatriz B = A - I:\n{B}")
# Out:
# Matriz A:
# [[2 1]
#  [1 2]]
#
# Matriz Identidade:
# [[1 0]
#  [0 1]]
#
# Matriz B = A - I:
# [[1 1]
#  [1 1]]

# %% [markdown]
# Os operadores não precisam nem ter exatamente as mesmas dimensões.

# %%
C = A + u

print(f"Matriz A:\n{A}\nVetor u:\n{u}\n\nMatriz C = A + u:\n{C}")
# Out:
# Matriz A:
# [[2 1]
#  [1 2]]
# Vetor u:
# [1 3]
#
# Matriz C = A + u:
# [[3 4]
#  [2 5]]

# %% [markdown]
# Para realizarmos a multiplicação de matrizes também podemos utilizar NumPy. Desde que observe-se a regra de colunas e linhas compatíveis entre os operadores.

# %%
D = np.matmul(A, I)

print(f"Matriz A:\n{A}\n\nMatriz Identidade:\n{I}\n\nMatriz D = A x I:\n{D}")
# Out:
# Matriz A:
# [[2 1]
#  [1 2]]
#
# Matriz Identidade:
# [[1 0]
#  [0 1]]
#
# Matriz D = A x I:
# [[2 1]
#  [1 2]]

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas aulas iremos compreender como essa estrutura de dados e operações fornecidas pela biblioteca NumPy são funcionais para os problemas comuns em Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://numpy.org/devdocs/user/absolute_beginners.html
# - https://www.geogebra.org/
# - https://numpy.org/devdocs/user/whatisnumpy.html
# - https://numpy.org/devdocs/user/quickstart.html

# %% [markdown]
# ## Atividades Complementares (Opicional)

# %% [markdown]
# Faça operações com outras matrizes.
#
# - [ ] Existe outra forma de instaciar matrizes e vetores especiais (matriz identidade, vetor nulo, etc)?
# - [ ] Existe outra forma de realizar as operações que chamamos da biblioteca (np.dot, np.matmul)?
# - [ ] É possível trabalhar com arrays multi-dimensionais? Faça alguns testes com vetores e matrizes 3D.

# %% [markdown]
# ### Outras Formas de Instanciar Matrizes e Vetores especiais

# %%
vetor_zeros = np.zeros(3)
vetor_uns = np.ones(3)
matriz_zeros = np.zeros((2, 3))
matriz_uns = np.ones((2, 3))
matriz_identidade_eye = np.eye(3)
matriz_identidade_identity = np.identity(3)
matriz_identidade_rect = np.eye(2, 4)
matriz_diagonal = np.diag([1, 2, 3])
matriz_para_extrair = np.array([[5, 9], [7, 3]])
matriz_diagonal_extraida = np.diag(matriz_para_extrair) 

print(f"Vetor de Zeros: \n{vetor_zeros}")
print(f"Vetor de Uns: \n{vetor_uns}")
print(f"Matriz de Zeros (2x3): \n{matriz_zeros}")
print(f"Matriz de Uns (2x3): \n{matriz_uns}")
print(f"Matriz Identidade com eye: \n{matriz_identidade_eye}")
print(f"Matriz Identidade com Identity: \n{matriz_identidade_identity}")
print(f"Matriz Identidade com eye (2, 4): \n{matriz_identidade_rect}")
print(f"Matriz Diagonal: \n{matriz_diagonal}")
print(f"Matriz Diagonal extraida de 'matriz_para_extrair': \n{matriz_diagonal_extraida}")
# Out:
# Vetor de Zeros:
# [0. 0. 0.]
# Vetor de Uns:
# [1. 1. 1.]
# Matriz de Zeros (2x3):
# [[0. 0. 0.]
#  [0. 0. 0.]]
# Matriz de Uns (2x3):
# [[1. 1. 1.]
#  [1. 1. 1.]]
# Matriz Identidade com eye:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Matriz Identidade com Identity:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Matriz Identidade com eye (2, 4):
# [[1. 0. 0. 0.]
#  [0. 1. 0. 0.]]
# Matriz Diagonal:
# [[1 0 0]
#  [0 2 0]
#  [0 0 3]]
# Matriz Diagonal extraida de 'matriz_para_extrair':
# [5 3]

# %% [markdown]
# ### Operações com 'np.dot' e 'np.matmul'

# %%
arr1 = np.array([1, 3])
arr2 = np.array([3, 1])
matriz = np.array([[2, 1], [1, 2]])
identidade = np.eye(2)

# Vetores
result_1 = np.dot(arr1, arr2)
result_2 = arr1.dot(arr2)
result_3 = np.inner(arr1, arr2)

# Matrizes
produto_matriz_1 = np.matmul(matriz, identidade)
produto_matriz_2 = matriz @ identidade
produto_matriz_3 = matriz.dot(identidade)

print(f"Função np.dot: \n {result_1}")
print(f"Método .dot() do próprio array: \n {result_2}")
print(f"Utilizando np.inner: \n {result_3}")

print(f"Utilizando MatMul: \n {produto_matriz_1}")
print(f"Utilizando @: \n {produto_matriz_2}")
print(f"Utilizando .dot() (para matrizes 2D): \n {produto_matriz_3}")
# Out:
# Função np.dot:
#  6
# Método .dot() do próprio array:
#  6
# Utilizando np.inner:
#  6
# Utilizando MatMul:
#  [[2. 1.]
#  [1. 2.]]
# Utilizando @:
#  [[2. 1.]
#  [1. 2.]]
# Utilizando .dot() (para matrizes 2D):
#  [[2. 1.]
#  [1. 2.]]
