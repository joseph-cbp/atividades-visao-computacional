# %% [markdown]
# # M3A5 - Detecção de objetos

# %% [markdown]
# Na prática de hoje vamos utilizar um modelo pré-treinado para detecção de objetos. Para a prática de hoje iremos utilizar a biblioteca  [Ultralytics](https://docs.ultralytics.com/).
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Detecção de Objetos
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.4/833.4 kB 46.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 MB 27.2 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 40.4 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [ultralytics] [ultralytics]me-32]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importar as bibliotecas e Ler Imagens do Disco

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import torchvision
import ultralytics

# %%
# TODO Atualize o path da imagem.
image = cv2.imread("street.jpeg")

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Detecção de Objetos
#
# Iremos carregar o modelo pré treinado e visualizar seus resultados.

# %%
# Load a pretrained YOLO11n model
model = ultralytics.YOLO("yolo11n.pt")

# Roda a inferência do modelo YOLO.
results = model(image)

for i, result in enumerate(results):
    # Salva os resultados em uma imagem no disco.
    result.save(filename=f"results_{i}.jpg")

# Carrega a imagem que acabou de ser salva para visualizarmos.
results_image = cv2.imread("results_0.jpg")
plt.imshow(cv2.cvtColor(results_image, cv2.COLOR_BGR2RGB))
# Out:
# ...
#
# 0: 448x640 4 persons, 15 cars, 1 bus, 55.8ms
# Speed: 3.5ms preprocess, 55.8ms inference, 5.3ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# E basta isso para detectarmos objetos que a [YOLO](https://arxiv.org/pdf/1506.02640) foi treinada para detectar.

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas iremos ver outras tarefas clássicas de Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://docs.ultralytics.com/
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opicional)

# %% [markdown]
# - [ ] Explore a biblioteca e tente rodar o modelo utilizando linha de comando e com outras opções.

# %%
# !yolo detect predict model=yolo11n.pt source=street.jpeg
# Out:
# Ultralytics 8.4.66 🚀 Python-3.14.3 torch-2.12.0 CPU (Apple M2 Pro)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 /Users/joseph-cbp/Documents/Visão Computacional/VC - Mod03/VC_M3A5 - Detecção de objetos/street.jpeg: 448x640 4 persons, 15 cars, 1 bus, 35.5ms
# Speed: 4.7ms preprocess, 35.5ms inference, 6.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/joseph-cbp/Documents/Visão Computacional/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=yolo11n.pt source=street.jpeg show_labels=False show_conf=False
# Out:
# Ultralytics 8.4.66 🚀 Python-3.14.3 torch-2.12.0 CPU (Apple M2 Pro)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 /Users/joseph-cbp/Documents/Visão Computacional/VC - Mod03/VC_M3A5 - Detecção de objetos/street.jpeg: 448x640 4 persons, 15 cars, 1 bus, 33.9ms
# Speed: 5.3ms preprocess, 33.9ms inference, 4.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/joseph-cbp/Documents/Visão Computacional/runs/detect/predict-2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=yolo11n.pt source=0 show=True
# Out:
# Ultralytics 8.4.66 🚀 Python-3.14.3 torch-2.12.0 CPU (Apple M2 Pro)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# 1/1: 0... Success ✅ (inf frames of shape 1920x1080 at 30.00 FPS)
#
# 0: 384x640 1 person, 41.6ms
# 0: 384x640 1 person, 30.5ms
# 0: 384x640 1 person, 29.2ms
# 0: 384x640 1 person, 29.1ms
# 0: 384x640 1 person, 30.1ms
# 0: 384x640 1 person, 29.1ms
# 0: 384x640 1 person, 30.4ms
# 0: 384x640 1 person, 29.2ms
# 0: 384x640 1 person, 29.6ms
# 0: 384x640 1 person, 30.2ms
# 0: 384x640 1 person, 32.8ms
# 0: 384x640 1 person, 31.0ms
# 0: 384x640 1 person, 32.4ms
# 0: 384x640 1 person, 28.6ms
# 0: 384x640 1 person, 29.2ms
# 0: 384x640 1 person, 34.3ms
# 0: 384x640 1 person, 29.4ms
# 0: 384x640 1 person, 31.4ms
# 0: 384x640 1 person, 30.5ms
# 0: 384x640 1 person, 27.1ms
# 0: 384x640 1 person, 39.7ms
# 0: 384x640 1 person, 26.1ms
# 0: 384x640 1 person, 26.5ms
# 0: 384x640 1 person, 28.9ms
# 0: 384x640 1 person, 28.3ms
# ...

# %%
# !yolo pose predict model=yolo11n-pose.pt source=street.jpeg
